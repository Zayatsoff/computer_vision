# %% [markdown]
# ## Facial landmark detection
# Code adapted from https://github.com/cunjian/pytorch_face_landmark},by Cunjian Chen

# %%
# Needs Cyphlon
# Only needs to be run once
# %%cmd
python models/pytorch_face_landmark-master_edited/FaceBoxes/utils/build.py build_ext --inplace

# %%
# %%cmd
# python models/pytorch_face_landmark-master_edited/test_batch_detections.py --backbone MobileFaceNet --detector Retinaface --imgdir images/source/*.JPG
# Out:
# Microsoft Windows [Version 10.0.19044.1766]
# (c) Microsoft Corporation. All rights reserved.
#
# c:\Users\timur\miniconda3\envs\cnncourse\FacialProcessing>python models/pytorch_face_landmark-master_edited/test_batch_detections.py --backbone MobileFaceNet --detector Retinaface --imgdir images/source/*.JPG
# Use MobileFaceNet as backbone
# images/source\img_01.JPG
# Loading pretrained model from models\pytorch_face_landmark-master_edited\Retinaface\weights\mobilenet0.25_Final.pth
# remove prefix 'module.'
# Missing keys:0
# Unused checkpoint keys:0
# Used keys:300
# net forward time: 0.0414
# Time: 0.212432s.
# c:\Users\timur\miniconda3\envs\cnncourse\FacialProcessing\models\pytorch_face_landmark-master_edited\utils\matlab_cp2tform.py:80: FutureWarning: `rcond` parameter will change to the default of machine precision times ``max(M, N)`` where M and N are the input matrix dimensions.
# To use the future default and silence this warning we advise to pass `rcond=None`, to keep using the old, explicitly pass `rcond=-1`.
#   r, _, _, _ = lstsq(X, U)
# images/source\img_02.JPG
# Loading pretrained model from models\pytorch_face_landmark-master_edited\Retinaface\weights\mobilenet0.25_Final.pth
# remove prefix 'module.'
# Missing keys:0
# Unused checkpoint keys:0
# Used keys:300
# net forward time: 0.0399
# Time: 0.227391s.
#
# c:\Users\timur\miniconda3\envs\cnncourse\FacialProcessing>

# %%
# %matplotlib inline 
import matplotlib.pyplot as plt
from skimage.io import imread
import os

# %%
imgdir = 'images/source/'
for item in os.listdir(imgdir):
    f = os.path.join(imgdir, item)
    image = imread(f)
    plt.figure()
    plt.imshow(image)
